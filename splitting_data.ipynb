# %%
import pandas as pd

# %%
df = pd.read_excel('smalleyeball.xlsx')

# %%
df_firsthalf = df.iloc[:int(len(df)/2)]

# %%
int(len(df)/2)
# Out:
# 3392

# %%
df_firsthalf
# Out:
#       Unnamed: 0  index                                               text  \
# 0              9      9  So apparently IU is catching on and wonвЂ™t ju...
# 1             82     82  The 11 Year Customer: Last week, I met a VP of...
# 2            107    107  7 Reasons to Choose Adobe Sign for E-Signature...
# 3            115    115  What is it with ink discrimination? I was just...
# 4            129    129  Explore Adobe Sign, a web base tool used for d...
# 5            132    132  New version of Adobe Flash Player for Windows ...
# 6            143    143  Adobe Fill &amp; Sign users, you can get aroun...
# 7            151    151  Sign up for Coastline's Online DGA C164 Adobe ...
# 8            163    163  Sapho Employee Experience Portal 4.9 is here! ...
# 9            167    167  Sign up today for our summer 2018 classes! Top...
# 10           186    186  Why wonвЂ™t Adobe Illustrator the detect Phili...
# ...

# %%
df_secondhalf = df.iloc[int(len(df)/2):]

# %%
df_secondhalf
# Out:
#       Unnamed: 0  index                                               text  \
# 3392       15694  15694  Docusign $DOCU Shares Down 5.4% https://t.co/c...
# 3393       15695  15695  @DocuSign @DanDSpringer - A big Congratulation...
# 3394       15696  15696  Reminded of the Netflix lawsuit discovery show...
# 3395       15697  15697  DocuSign founder and chairman leaving board in...
# 3396       15698  15698  #DocuSign founder and chairman leaving board i...
# 3397       15699  15699  @Edelman215 @DocuSign @HelloSign @apollographq...
# 3398       15700  15700  @AaronKlein Client recвЂ™d multiple emails wit...
# 3399       15701  15701  @DocuSign @Blakei @SteveSSingh @Inhicho Welcom...
# 3400       15702  15702          @KeithJKrach @DocuSign Hell of a journey.
# 3401       15703  15703  How Docusign Works For People Selling A Home O...
# 3402       15705  15705  $DOCU Docusign - A Bullish Reversal Pattern Se...
# ...

# %%
len(df)
# Out:
# 6784

# %%
3392*2
# Out:
# 6784

# %%
df_secondhalf.to_excel("smalleyeball_parttwo.xlsx", sheet_name='Sheet_name_1')
df_firsthalf.to_excel("smalleyeball_partone.xlsx", sheet_name='Sheet_name_1')
